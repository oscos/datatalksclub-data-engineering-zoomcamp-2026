# %%
import pandas as pd
from sqlalchemy import create_engine
import os

# Use environment variables defined in docker-compose.yml
PG_USER = os.getenv("POSTGRES_USER", "root")
PG_PASSWORD = os.getenv("POSTGRES_PASSWORD", "root")
PG_DB = os.getenv("POSTGRES_DB", "ny_taxi")
PG_HOST = os.getenv("POSTGRES_HOST", "postgres")
PG_PORT = os.getenv("POSTGRES_PORT", "5432")

# Create the connection string
conn_str = f"postgresql://{PG_USER}:{PG_PASSWORD}@{PG_HOST}:{PG_PORT}/{PG_DB}"
engine = create_engine(conn_str)

# %%
# Example: fetch first 5 rows
df = pd.read_sql("SELECT * FROM yellow_taxi_trips_2021_01 LIMIT 5;", engine)
df
# Out:
#    index  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0      0         1  2021-01-01 00:30:10   2021-01-01 00:36:12
# 1      1         1  2021-01-01 00:51:20   2021-01-01 00:52:19
# 2      2         1  2021-01-01 00:43:30   2021-01-01 01:11:06
# 3      3         1  2021-01-01 00:15:48   2021-01-01 00:31:01
# 4      4         2  2021-01-01 00:31:49   2021-01-01 00:48:21
#
#    passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0                1           2.10           1                  N
# 1                1           0.20           1                  N
# 2                1          14.70           1                  N
# 3                0          10.60           1                  N
# 4                1           4.94           1                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# 0           142            43             2          8.0    3.0      0.5
# ...
